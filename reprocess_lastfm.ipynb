# %%
import pandas as pd
import numpy as np
import os

# %%
file_path = "reindexed_sessions.csv"

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#         sep  user_id                  timestamp  \
# 0         1        1  2007-03-01 04:37:37+00:00
# 1         1        1  2007-03-01 04:39:18+00:00
# 2         1        1  2007-03-01 04:43:00+00:00
# 3         1        1  2007-03-01 04:45:30+00:00
# 4         1        1  2007-03-01 04:47:15+00:00
# ...     ...      ...                        ...
# 23801  1213      177  2008-05-22 00:15:03+00:00
# 23802  1213      177  2008-05-22 00:22:12+00:00
# 23803  1213      177  2008-05-22 00:25:51+00:00
# 23804  1213      177  2008-05-22 00:33:00+00:00
# 23805  1213      177  2008-05-22 00:36:39+00:00
#
#                                   artist_id      artist_name  track_id  \
# 0      f1571db1-c672-4a54-a2cf-aaa329f26f0b  John Frusciante         1
# 1      f1571db1-c672-4a54-a2cf-aaa329f26f0b  John Frusciante         1
# 2      03ad1736-b7c9-412a-b442-82536d63a5c4    Elliott Smith         2
# 3      ff6e677f-91dd-4986-a174-8db0474b1799     Jack Johnson         3
# ...
